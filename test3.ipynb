# %%
import sys
sys.path.append('third_party/Matcha-TTS')
from cosyvoice.cli.cosyvoice import AutoModel
import torchaudio

""" CosyVoice Usage, check https://fun-audio-llm.github.io/ for more details
"""
cosyvoice = AutoModel(model_dir='pretrained_models/CosyVoice-300M-Instruct')
# instruct usage, support <laughter></laughter><strong></strong>[laughter][breath]
for i, j in enumerate(cosyvoice.inference_instruct('CosyVoice is undergoing a comprehensive upgrade, providing more accurate, stable, faster, and better voice generation capabilities.', '中文男',
                                                    'Theo \'Crimson\', is a fiery, passionate rebel leader. Fights with fervor for justice, but struggles with impulsiveness.<|endofprompt|>')):
    torchaudio.save('instruct_{}.wav'.format(i), j['tts_speech'], cosyvoice.sample_rate)
# for i, j in enumerate(cosyvoice.inference_instruct('在面对挑战时，他展现了非凡的<strong>勇气</strong>与<strong>智慧</strong>。', '中文男',
#                                                     'Theo \'Crimson\', is a fiery, passionate rebel leader. Fights with fervor for justice, but struggles with impulsiveness.<|endofprompt|>')):
#     torchaudio.save('instruct_{}.wav'.format(i), j['tts_speech'], cosyvoice.sample_rate)
# Out:
# 2026-06-05 12:36:52,284 INFO input frame rate=50
# 2026-06-05 12:36:52.986220983 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 12 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2026-06-05 12:36:52.987069339 [W:onnxruntime:, session_state.cc:1166 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2026-06-05 12:36:52.987074927 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# 2026-06-05 12:36:53,120 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# Downloading Model to directory: /home/shin.nishimura/.cache/modelscope/hub/pengzhendong/wetext
# 2026-06-05 12:36:54,186 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/pengzhendong/wetext/revisions HTTP/1.1" 200 222
# 2026-06-05 12:36:54,539 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/pengzhendong/wetext/repo/files?Revision=master&Recursive=True HTTP/1.1" 200 None
# 2026-06-05 12:36:54,655 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# Downloading Model to directory: /home/shin.nishimura/.cache/modelscope/hub/pengzhendong/wetext
# 2026-06-05 12:36:55,752 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/pengzhendong/wetext/revisions HTTP/1.1" 200 222
# 2026-06-05 12:36:56,100 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/pengzhendong/wetext/repo/files?Revision=master&Recursive=True HTTP/1.1" 200 None
# 2026-06-05 12:36:56,169 INFO use wetext frontend
#   0%|          | 0/1 [00:00<?, ?it/s]2026-06-05 12:36:57,272 INFO synthesis text CosyVoice is undergoing a comprehensive upgrade, providing more accurate, stable, faster, and better voice generation capabilities.
# 2026-06-05 12:36:59,278 INFO yield speech len 6.873106575963718, rtf 0.2918064606067649
# 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]

# %%
for i, j in enumerate(
    cosyvoice.inference_instruct(
        'CosyVoice is undergoing a comprehensive upgrade, providing more accurate, stable, faster, and better voice generation capabilities.', 
        '中文男',
        'Theo \'Crimson\', is a fiery, passionate rebel leader. Fights with fervor for justice, but struggles with impulsiveness.<|endofprompt|>'
        )
    ):
    torchaudio.save('instruct_{}.wav'.format(i), j['tts_speech'], cosyvoice.sample_rate)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]2026-06-05 12:43:20,664 INFO synthesis text 権利幸福きらいな人に。自由湯をば飲ましたい。
# 2026-06-05 12:43:22,758 INFO yield speech len 4.388571428571429, rtf 0.4771875760828455
# 100%|██████████| 1/1 [00:02<00:00,  2.11s/it]
